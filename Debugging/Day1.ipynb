# %%
import numpy as np

data = np.array([10, 20, 30])
mean = np.mean(data, axis=1)
print(mean)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import numpy as np
#       3 data = np.array([10, 20, 30])
# ----> 4 mean = np.mean(data, axis=1)
#       5 print(mean)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\_core\fromnumeric.py:3904, in mean(a, axis, dtype, out, keepdims, where)
#    3901     else:
#    3902         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3904 return _methods._mean(a, axis=axis, dtype=dtype,
#    3905                       out=out, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\numpy\_core\_methods.py:124, in _mean(a, axis, dtype, out, keepdims, where)
#     120 arr = asanyarray(a)
#     122 is_float16_result = False
# --> 124 rcount = _count_reduce_items(arr, axis, keepdims=keepdims, where=where)
#     125 if rcount == 0 if where is True else umr_any(rcount == 0, axis=None):
# ...

# %%
import numpy as np

data = np.array([10, 20, 30])
mean = np.mean(data)
print(mean)
# Out:
# 20.0

# %%
data = np.array([10, 20, 30])
mean = np.mean(data, axis=0)
print(mean)
# Out:
# 20.0

# %%
data = data.reshape(1, -1)
np.mean(data, axis=1)
# Out:
# array([20.])

# %%
from sklearn.model_selection import train_test_split

X = [[1], [2], [3], [4]]
y = [10, 20, 30, 40]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0)
print(len(X_test))
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[4], line 6
#       3 X = [[1], [2], [3], [4]]
#       4 y = [10, 20, 30, 40]
# ----> 6 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0)
#       7 print(len(X_test))
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py:206, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     203 to_ignore += ["self", "cls"]
#     204 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 206 validate_parameter_constraints(
#     207     parameter_constraints, params, caller_name=func.__qualname__
#     208 )
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
#
# ...

# %%
X = [[1], [2], [3], [4]]
y = [10, 20, 30, 40]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25)
print(len(X_test))
# Out:
# 1

# %% [markdown]
# ##### What is the test size in train test split?
#
# * test_size is 1-train_size. 80% of the data is train set, so 20% of our data is our test set. If we don't specify the sizes of test and train sets by default test_size will be 0.25.
#
# ##### What does test_size 0.2 mean?
# * X_test and y_test are the test sets. test_size=0.2 means 20% of the data is for testing, and 80% is for training. It is common to use 20-30% of your data for the test set. random_state=42 ensures the split is the same every time you run the code, which is handy for reproducibility.
#
# ##### What is x_train, x_test, y_train, y_test?
# * x_train and y_train represent the inputs and outputs of the training data subset, respectively, while x_test and y_test represent the input and output of the testing data subset. By specifying test_size=0.2 , you use 20% of the dataset for testing, leaving 80% for training.
#
# ##### How to choose the right train split size?
# * Common split ratios include ` 70% training, 15% validation, 15% test, or 80% training, 10% validation, 10% test. For simpler train-test splits, 75% training and 25% testing, or 80% training and 20% testing`, are common.
#
# ` test_size `
#
# * float or int, default=None
# If float, should be between 0.0 and 1.0 and represent the proportion of the dataset to include in the test split. If int, represents the absolute number of test samples. If None, the value is set to the complement of the train size. If train_size is also None, it will be set to 0.25.
# *****
# ` train_size `
#
# * float or int, default=None
# If float, should be between 0.0 and 1.0 and represent the proportion of the dataset to include in the train split. If int, represents the absolute number of train samples. If None, the value is automatically set to the complement of the test size.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

from sklearn.model_selection import train_test_split

y_true = [1, 0, 1, 1]
y_pred = [1, 1, 1, 0]

acc = accuracy_score(y_pred, y_true)
# 1st argument → actual labels
# 2nd argument → model predictions
print(acc)
# Out:
# 0.5

# %%
y_true = [1,1,1,0]
y_pred = [1,0,1,1]

acc = accuracy_score(y_true, y_pred)
print(acc)
# Out:
# 0.5

# %% [markdown]
# * Root cause:
#
# `accuracy_score assumes first argument is ground truth.
# You violated the contract.`
