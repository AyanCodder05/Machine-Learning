# %%
from sklearn import datasets

housing=datasets.fetch_california_housing()

x=housing.data
y=housing.target

print(housing.feature_names)
print(x[0])
print(y[0])
# Out:
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
# [   8.3252       41.            6.98412698    1.02380952  322.
#     2.55555556   37.88       -122.23      ]
# 4.526

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,
                 y, 
                 test_size=0.2,
                random_state=432                                
                
                                                 )
print(x_train[0])
print(y_train[0])
# Out:
# [   2.1442       52.            3.94886364    1.03693182  921.
#     2.61647727   37.34       -121.88      ]
# 1.889

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train, y_train)
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.6080229586580355

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures()
print(x.shape)
x=poly.fit_transform(x)
print(x.shape)
print(r2)
# Out:
# (20640, 45)
# (20640, 1081)
# 0.6080229586580355

# %%
from sklearn.ensemble import (GradientBoostingRegressor, RandomForestRegressor)
LR=LinearRegression()
GBR=GradientBoostingRegressor()
RFR=RandomForestRegressor(
    n_jobs=-1
)
for i in[LR, GBR, RFR]:
    i.fit(x_train, y_train)
    y_pred=i.predict(x_test)
    r2=r2_score(y_test, y_pred)
    print(i,r2)
# Out:
# LinearRegression() 0.6080229586580355
# GradientBoostingRegressor() 0.7878126561044645
# RandomForestRegressor() 0.8126802208252757

# %%
from sklearn.ensemble import (HistGradientBoostingRegressor, RandomForestRegressor)
LR=LinearRegression()
GBR=HistGradientBoostingRegressor()
RFR=RandomForestRegressor(
    n_jobs=-1
)
for i in[LR, GBR, RFR]:
    i.fit(x_train, y_train)
    y_pred=i.predict(x_test)
    r2=r2_score(y_test, y_pred)
    print(i,r2)
# Out:
# LinearRegression() 0.6080229586580355
# HistGradientBoostingRegressor() 0.8374163107136409
# RandomForestRegressor(n_jobs=-1) 0.8139418403328251

# %%
# for i in[100,150,200,250,300,350]:
#     model=HistGradientBoostingRegressor(
#         max_iter=i
#     )
#     model.fit(x_train, y_train)
#     y_pred=model.predict(x_test)
#     r2=r2_score(y_test, y_pred)
#     print(i,r2)
# Out:
# 100 0.835147859548529
# 150 0.8370616655841034
# 200 0.8444766067117114
# 250 0.8416369388342332
# 300 0.8449194299094979
# 350 0.8422433090650192

# %%
# for j in [0.1,0.05,0.001]:
#     for i in[250,200,350]:
#         model=HistGradientBoostingRegressor(
#         max_iter=i,
#         learning_rate=j
#         )
#         model.fit(x_train, y_train)
#         y_pred=model.predict(x_test)
#         r2=r2_score(y_test, y_pred)
#         print(i,j,r2)
# Out:
# 250 0.1 0.8454381537956457
# 200 0.1 0.8455357357689177
# 350 0.1 0.8419054002221829
# 250 0.05 0.8403933844691405
# 200 0.05 0.8356518109119931
# 350 0.05 0.8408534968520689
# 250 0.001 0.2611009468717097
# 200 0.001 0.21775038226088184
# 350 0.001 0.33644562828660496

# %%
model=HistGradientBoostingRegressor(
        max_iter=350,
        learning_rate=0.05
        )
model.fit(x_train, y_train)
y_pred=model.predict(x_test)
r2=r2_score(y_test, y_pred)
print(r2)
# Out:
# 0.8442510624369377

# %%
import joblib
joblib.dump(model,"scikit_learn_basic_with.joblib")
# Out:
# ['scikit_learn_basic_with.joblib']
